# %% [markdown]
# # Super Aula de Pandas

# %% [markdown]
# ## Historia de pandas
#
# ....

# %% [markdown]
# ## Requisitos ter python instalado ou anaconda
# eu vou usar o python puro purque tambem, uso para backend e varias outras coisas se nao tiveres podes instal o anaconda ou o python
# vou deixar o requirements.txt que tem tudo que precisa para este curso
#
# [Python]()
#
# [Anaconda]()
#
# ### Instalacao
#
# o pandas nao vem direto no pyhon enato deve instala
#
# #### 1 Inicia o  projecto
#
# Dentro do diretorio onde esta o seu projecto digita o seguite comando
#
# ```bash
# python -m venv venv
# ```
#
# apois diddo devars um diretorio chamado venv/
#
# Depois precisas ativar o seu abiente virtual
#
# - linux
#
# ```bash
# source venv/bin/acivate
# ```
#
# apis isso veras que o teu terminal mudou agora est assim:
#
# antes
# ```bash
# ┌──(custcoding㉿kali)-[~/learn-repo/Python/libs/pandas]
# └─$
# ```
# depois de executar o comando
# ```bash
# ┌──(venv)─(custcoding㉿kali)-[~/learn-repo/Python/libs/pandas]
# └─$
# ```
#
# o (venv) mostra que o seu abiente virtual esta ativo apois isso podes intalar o pandas
#
# para instalar no terminal vaiis executar o comando `pip install pandas` esse comando instala a biblioteca pandas
